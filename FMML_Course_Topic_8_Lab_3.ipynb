# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavikarri123/FMML/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 07:47:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   147MB/s    in 0.5s
#
# 2024-03-31 07:47:40 (147 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12585  1803.02398v1  Protein-ligand scoring is an important step in...  stat
# 24952  1501.03069v2  Many visual surveillance tasks, e.g.video summ...    cs
# 21917  1502.06689v1  We consider the problem of noisy 1-bit matrix ...  stat
# 28     1709.01215v2  We investigate the non-identifiability issues ...  stat
# 39008  1503.03732v1  Recognition of intentions is a subconscious co...    cs
# ...             ...                                                ...   ...
# 5776    1206.4650v1  In real supervised learning scenarios, it is n...    cs
# 3401   1611.07492v1  We develop a framework for incorporating struc...  stat
# 11562  1606.02109v2  Users of a personalised recommendation system ...  stat
# 17287  1710.00803v1  This technical report describes the framework ...    cs
# 6006   1605.08833v1  We explore a novel approach to semi-supervised...    cs
#
#                                                    title  year  \
# 12585  Visualizing Convolutional Neural Network Prote...  2018
# 24952  Learning from Multiple Sources for Video Summa...  2015
# 21917  1-Bit Matrix Completion under Exact Low-Rank C...  2015
# 28     ALICE: Towards Understanding Adversarial Learn...  2017
# 39008  Starting engagement detection towards a compan...  2015
# ...                                                  ...   ...
# 5776   Analysis of Kernel Mean Matching under Covaria...  2012
# 3401   Inducing Interpretable Representations with Va...  2016
# 11562  Efficient differentially private learning impr...  2016
# 17287  Compiling and Processing Historical and Contem...  2017
# 6006                    Muffled Semi-Supervised Learning  2016
#
#                                                 keywords
# 12585  [important, structure, selecting, predicting, ...
# 24952  [surveillance, summarisation, conventionally, ...
# 21917  [completion, constraint, underlying, observing...
# 28     [investigate, identifiability, associated, bid...
# 39008  [recognition, intentions, subconscious, cognit...
# ...                                                  ...
# 5776   [supervised, scenarios, different, probability...
# 3401   [framework, incorporating, structured, graphic...
# 11562  [personalised, recommendation, recommendations...
# 17287  [technical, describes, framework, processing, ...
# 6006   [supervised, unlabeled, algorithm, experimenta...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12585    [important, structure, selecting, predicting, ...
# 24952    [surveillance, summarisation, conventionally, ...
# 21917    [completion, constraint, underlying, observing...
# 28       [investigate, identifiability, associated, bid...
# 39008    [recognition, intentions, subconscious, cognit...
#                                ...
# 6307     [investigate, generative, modalities, directio...
# 26526    [similarity, introduced, similarity, effective...
# 23475    [properties, limitations, efficiently, compres...
# 29355    [techniques, accelerate, alternating, directio...
# 6310     [distributionally, supervised, necessary, perf...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8810 words.
# Out of those 4501 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5b756ab5-7d77-435a-b1e8-05052a907254" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b756ab5-7d77-435a-b1e8-05052a907254")) {                    Plotly.newPlot(                        "5b756ab5-7d77-435a-b1e8-05052a907254",                        [{"x":["functions","interpret","convolutional","individual","parameters","particular","prediction","available","selecting","structure","difficult","visualization","predicting","decisions","visualizations","complexes","selection","visualizing","screening","performance","techniques","important","structural","intuition","understanding","decompose","increasing","effective","interpreted","heterogeneous","different","observations","previously","comprehensive","inferring","mechanism","unsupervised","discovering","surveillance","associating","meaningful","generated","framework","independently","incomplete","conducted","complement","accomplished","semantics","conventionally","summarisation","representation","clustering","unreliable","trustworthy","accessible","analysing","investigate","dimension","accurately","sufficiently","completion","nonconvex","independent","convergence","continuous","factorization","optimization","iterative","likelihood","relaxations","constraint","estimation","measurements","algorithm","underlying","observing","probabilistic","dimensions","certificate","optimality","constrained","according","synthetic","approaches","introduce","stabilizes","conditional","distribution","theoretical","associated","identifiability","bidirectional","extension","desirable","distributions","applications","adversarial","supervised","validated","investigation","integrates","spontaneous","intentions","conditions","perspectives","evaluation","addressed","cognitive","intention","engagement","anticipation","communication","recognizing","multimodal","collected","highlights","validation","communicate","reduction","robustness","precision","perception","interaction","subconscious","environment","technique","sufficient","increases","originality","companion","investigated","inspiration","information","classically","experimental","demonstrate","validates","detection","recognition","researches","interactions","manipulating","computing","speculate","biological","substrate","experiments","implementation","including","computation","combinatorial","implementing","concurrent","identifying","historical","unethical","activities","inferential","correlation","discovery","causality","discriminatory","favoritism","databases","essentially","principled","attributes","addressing","structures","protected","requirement","causation","discrimination","following","inability","successfully","sentiment","interpretation","something","variables","contributions","predictions","importance","combinations","contextual","contrasting","decomposing","consequently","decomposition","relationships","characterized","embedding","exploring","represent","relatedness","efficiency","classification","annotation","computational"],"y":[235,18,355,112,239,280,214,316,37,337,148,25,84,60,7,7,150,9,11,880,362,356,48,21,167,20,111,277,15,34,741,80,92,77,21,94,176,24,38,9,55,187,522,36,35,64,19,9,111,5,2,352,141,16,4,15,14,130,63,76,21,24,11,137,114,121,35,304,84,54,6,93,203,46,792,128,19,154,42,1,26,62,103,117,411,329,1,98,227,153,99,3,17,81,42,117,405,110,216,34,35,22,4,9,152,12,289,39,44,7,5,5,69,29,35,81,11,63,12,92,109,81,46,79,1,136,222,72,36,2,2,38,5,698,6,397,532,3,362,378,11,62,9,124,2,48,4,607,126,270,148,35,26,5,78,27,1,42,2,77,56,7,4,2,63,22,28,54,28,140,3,26,5,23,85,3,95,46,63,7,153,46,92,68,28,51,5,7,41,58,85,22,86,45,125,9,185,473,60,278],"type":"bar"},{"x":["functions","interpret","convolutional","individual","parameters","par ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4501,), (4501, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>based</span> <span style=''>Approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predicting</span> <span style=''>Customer</span> <span style=''>Churn</span> <span style=''>in</span> <span style=''>Cellular</span> <span style=''>Network</span> <span style=''>Services</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Marketing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>states</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>more</span> <span style=''>costly</span> <span style=''>to</span> <span style=''>engage</span> <span style=''>a</span> <span style=''>new</span> <span style=''>customer</span> <span style=''>than</span> <span style=''>to</span> <span style=''>retain</span> <span style=''>an</span> <span style=''>existing</span> <span style=''>loyal</span> <span style=''>customer</span> <span style=''>Churn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>academics</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3500000000000001);'>practitioners</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectively</span> <span style=''>manage</span> <span style=''>and</span> <span style=''>control</span> <span style=''>customer</span> <span style=''>churn</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>retain</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>customers</span> <span style=''>As</span> <span style=''>churn</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>management</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>activity</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>companies</span> <span style=''>to</span> <span style=''>retain</span> <span style=''>loyal</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>customers</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.43859649122807004);'>correctly</span> <span style=''>predict</span> <span style=''>customer</span> <span style=''>churn</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3114754098360655);'>necessary</span> <span style=''>As</span> <span style=''>the</span> <span style=''>cellular</span> <span style=''>network</span> <span style=''>services</span> <span style=''>market</span> <span style=''>becoming</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style=''>customer</span> <span style=''>churn</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>management</span> <span style=''>has</span> <span style=''>become</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>task</span> <span style=''>for</span> <span style=''>mobile</span> <span style='background-color:rgba(0, 255, 0, 0.5333333333333332);'>communication</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operators</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>customer</span> <span style=''>churn</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>Low</span> <span style=''>rank</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Completion</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>of</span> <span style=''>tensors</span> <span style=''>or</span> <span style=''>high</span> <span style=''>order</span> <span style=''>arrays</span> <span style=''>attracts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>research</span> <span style=''>Current</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>on</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>primarily</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>recovery</span> <span style=''>from</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniformly</span> <span style=''>randomly</span> <span style=''>measured</span> <span style=''>entries</span> <span style=''>and</span> <span style=''>the</span> <span style=''>required</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>recovery</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>optimal</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>some</span> <span style=''>previous</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>NP</span> <span style=''>hard</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>via</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style=''>scheme</span> <span style=''>we</span> <span style=''>name</span> <span style=''>Cross</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>easy</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>third</span> <span style=''>order</span> <span style=''>tensor</span> <span style=''>of</span> <span style=''>Tucker</span> <span style=''>rank</span> <span style=''>(r</span> <span style=''>1</span> <span style=''>r</span> <span style=''>2</span> <span style=''>r</span> <span style=''>3)</span> <span style=''>in</span> <span style=''>p</span> <span style=''>1</span> <span style=''>by</span> <span style=''>p</span> <span style=''>2</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Non</span> <span style=''>Convex</span> <span style=''>Rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style=''>via</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Bayesian</span> <span style=''>Approach</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>that</span> <span style=''>require</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>of</span> <span style=''>minimal</span> <span style=''>rank</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>is</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intractable</span> <span style=''>NP</span> <span style=''>hard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consequently</span> <span style=''>the</span> <span style=''>convex</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style=''>used</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3571428571428572);'>surrogate</span> <span style=''>penalty</span> <span style=''>term</span> <span style=''>for</span> <span style=''>matrix</span> <span style=''>rank</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>that</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style=''>there</span> <span style=''>is</span> <span style=''>no</span> <span style=''>longer</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>that</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.43859649122807004);'>correctly</span> <span style=''>estimate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>of</span> <span style=''>interest</span> <span style='background-color:rgba(255, 0, 0, 0.3259911894273127);'>theoretical</span> <span style=''>special</span> <span style=''>cases</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>notwithstanding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consequently</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>build</span> <span style=''>upon</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6370967741935485);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>that</span> <span style=''>unlike</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>retains</span> <span style=''>the</span> <span style=''>same</span> <span style=''>globally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>point</span> <span style=''>es ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fairness</span> <span style=''>in</span> <span style=''>Criminal</span> <span style=''>Justice</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Assessments</span> <span style=''>The</span> <span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Art</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Objectives</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discussions</span> <span style=''>of</span> <span style=''>fairness</span> <span style=''>in</span> <span style=''>criminal</span> <span style=''>justice</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assessments</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>lack</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conceptual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>Rhetoric</span> <span style=''>too</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substitutes</span> <span style=''>for</span> <span style=''>careful</span> <span style=''>analysis</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>seek</span> <span style=''>to</span> <span style=''>clarify</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tradeoffs</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>kinds</span> <span style=''>of</span> <span style=''>fairness</span> <span style=''>and</span> <span style=''>between</span> <span style=''>fairness</span> <span style=''>and</span> <span style=''>accuracy</span> <span style=''>Methods</span> <span style=''>We</span> <span style=''>draw</span> <span style=''>on</span> <span style=''>the</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literatures</span> <span style=''>in</span> <span style=''>criminology</span> <span style=''>computer</span> <span style=''>science</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>examination</span> <span style=''>of</span> <span style=''>fairness</span> <span style=''>and</span> <span style=''>accuracy</span> <span style=''>in</span> <span style=''>criminal</span> <span style=''>justice</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assessments</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustration</span> <span style=''>using</span> <span style=''>data</span> <span style=''>from</span> <span style=''>arraignments</span> <span style=''>Results</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>there</span> <span style=''>are</span> <span style=''>at</span> <span style=''>least</span> <span style=''>six</span> <span style=''>kinds</span> <span style=''>of</span> <span style=''>fairness</span> <span style=''>some</span> <span style=''>of</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incompatible</span> <span style=''>with</span> <span style=''>one</span> <span style=''>another</span> <span style=''>and</span> <span style=''>with</span> <span style=''>accuracy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conclusions</span> <span style=''>Except</span> <span style=''>in</span> <span style=''>trivial</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12639138240574507)
# 	architecture (0.0933572710951526)
# 	experimental (0.14254937163375225)
# 	segmentation (0.07612208258527828)
# 	knowledge (0.1339317773788151)
# 	information (0.2506283662477558)
# 	convolutional (0.12746858168761221)
# 	detection (0.12998204667863555)
# 	different (0.2660682226211849)
# 	recognition (0.13572710951526032)
#
# Some Statistics words are:
# 	variational (0.10074441687344914)
# 	stochastic (0.1349875930521092)
# 	theoretical (0.14937965260545905)
# 	distribution (0.1771712158808933)
# 	statistical (0.15483870967741936)
# 	estimation (0.17121588089330025)
# 	dimensional (0.17270471464019851)
# 	algorithm (0.39503722084367243)
# 	inference (0.1990074441687345)
# 	regression (0.18461538461538463)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d34bc48e-6fd3-4d0f-b24b-701812044c47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d34bc48e-6fd3-4d0f-b24b-701812044c47")) {                    Plotly.newPlot(                        "d34bc48e-6fd3-4d0f-b24b-701812044c47",                        [{"x":["functions","interpret","convolutional","individual","parameters","particular","prediction","available","selecting","structure","difficult","visualization","predicting","decisions","visualizations","complexes","selection","visualizing","screening","performance","techniques","important","structural","intuition","understanding","decompose","increasing","effective","interpreted","heterogeneous","different","observations","previously","comprehensive","inferring","mechanism","unsupervised","discovering","surveillance","associating","meaningful","generated","framework","independently","incomplete","conducted","complement","accomplished","semantics","conventionally","summarisation","representation","clustering","unreliable","trustworthy","accessible","analysing","investigate","dimension","accurately","sufficiently","completion","nonconvex","independent","convergence","continuous","factorization","optimization","iterative","likelihood","relaxations","constraint","estimation","measurements","algorithm","underlying","observing","probabilistic","dimensions","certificate","optimality","constrained","according","synthetic","approaches","introduce","stabilizes","conditional","distribution","theoretical","associated","identifiability","bidirectional","extension","desirable","distributions","applications","adversarial","supervised","validated","investigation","integrates","spontaneous","intentions","conditions","perspectives","evaluation","addressed","cognitive","intention","engagement","anticipation","communication","recognizing","multimodal","collected","highlights","validation","communicate","reduction","robustness","precision","perception","interaction","subconscious","environment","technique","sufficient","increases","originality","companion","investigated","inspiration","information","classically","experimental","demonstrate","validates","detection","recognition","researches","interactions","manipulating","computing","speculate","biological","substrate","experiments","implementation","including","computation","combinatorial","implementing","concurrent","identifying","historical","unethical","activities","inferential","correlation","discovery","causality","discriminatory","favoritism","databases","essentially","principled","attributes","addressing","structures","protected","requirement","causation","discrimination","following","inability","successfully","sentiment","interpretation","something","variables","contributions","predictions","importance","combinations","contextual","contrasting","decomposing","consequently","decomposition","relationships","characterized","embedding","exploring","represent","relatedness","efficiency","classification","annotation","computational","incorporating","specifically","typically","knowledge","effectiveness","probability","effectively","absorbing","probabilities","efficient","associations","estimator","transformed","canonical","transformation","transformations","simultaneously","universal","generalizes","approximation","association","numerical","outperforms","illustrate","combining","similarity","minibatch","procedure","estimated","discussed","viewpoints","regularization","simulations","parameter","unlabeled","theoretic","functional","interpreting","linguistic","application","collection","algorithms","consensus","unrelated","similarities","documents","extracted","clustered","extraneous","collections","optimally","management","adjustable","isolati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	invariances
# 	interpolates
# 	isomorphism
# 	multiplying
# 	depression
# 	homeostasis
# 	transplantation
# 	alliterative
# 	langlands
# 	textitnot
# 	fibrillation
# 	deflation
# 	econometrics
# 	censoring
# 	unintentionally
# 	parametrisation
# 	ellipsoidal
# 	ergodicity
# 	connectome
# 	contractive
# Some words which never appear in Statistics papers:
# 	associating
# 	conventionally
# 	summarisation
# 	trustworthy
# 	spontaneous
# 	intentions
# 	anticipation
# 	originality
# 	classically
# 	speculate
# 	substrate
# 	favoritism
# 	absorbing
# 	passengers
# 	passenger
# 	commercially
# 	metaheuristic
# 	authoring
# 	convincing
# 	deformation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.091094556582486e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7791666666666667
